# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gensim,os,sklearn,tqdm

from collections import Counter
from datetime import datetime

from scipy.sparse import csr_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim import corpora
from gensim import models

# %matplotlib inline
# Out:
# C:\Users\Evan\AppData\Local\conda\conda\envs\env_futures\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# # load data

# %%
counter_dir="C:/Users/Evan/MyFile/Fortune-street/007 oil_price/oilprice_news_analyze/002 data/003 outcome_data/word_counter_data/"
txt_dir="C:/Users/Evan/MyFile/Fortune-street/007 oil_price/oilprice_news_analyze/002 data/002 corpus_data/token_pos_filtered_txt_data/"
# C:\Users\Evan\MyFile\Fortune-street\007 oil_price\oilprice_news_analyze\002 data\002 corpus_data\token_txt_data

list_counter_filenames=list(os.walk(counter_dir))[0][2]
print(list_counter_filenames)
list_txt_source=list(os.walk(txt_dir))[0][1]
print(list_txt_source)
def read_news_txt_file(aFilepath):
    token_list=[]
    with open(aFilepath,"r",encoding='utf8') as f:
        news_title=f.readline()
        line = news_title
        while line :
            line = f.readline()
            token_list.append(line.strip())
    return(news_title,token_list)
full_list=[]
for aSource in list_txt_source:
    for subpath , null , list_news_filenames in tqdm.tqdm(list(os.walk(txt_dir+aSource))[1:]):
        news_publish_date=subpath.split("\\")[1]
        source=subpath.split("\\")[0].split("/")[-1]
        for aFilename in list_news_filenames:
            aFilepath="/".join([subpath, aFilename])
            news_title,news_tokens_list=(read_news_txt_file(aFilepath))
            
            out_dict={'news_publish_date':news_publish_date,
                      'news_title':news_title,
                      'news_tokens_list':news_tokens_list,
                      'source':source}
            full_list.append(out_dict)
full_news_df=pd.DataFrame(full_list)
full_news_df.head(10)
# Out:
# ['word_counter.npy', 'word_counter_2019_02_08.npy', 'word_counter_2019_02_12.npy', 'word_counter_2019_02_26.npy']
# ['cnbc_news_data', 'oil_price_news_data', 'uk_reuters_news_data']
# ...
# 100%|██████████| 373/373 [02:31<00:00,  3.27it/s]
#   news_publish_date                                         news_title  \
# 0        2018-12-04  update 3-oil prices skid with global stock mar...
# 1        2018-12-04  u.s. oil prices slide with global markets on e...
# 2        2018-12-04  heating oil futures turn negative in post-sett...
# 3        2018-12-04  oil futures fall in post-settlement trade afte...
# 4        2018-12-05  update 1-oil prices dip as stock markets slide...
# 5        2018-12-05  oil prices ease in cautious trading ahead of o...
# 6        2018-12-05  oil prices extend gains, brent crude up by mor...
# 7        2018-12-05  update 5-oil prices fall on global growth conc...
# 8        2018-12-05  update 4-oil prices slip on global growth conc...
# ...

# %%
first_date=full_news_df.news_publish_date.unique()[0]
full_history_df=pd.read_csv("C:\\Users\\Evan\\MyFile\\Fortune-street\\007 oil_price\
\\oilprice_news_analyze\\002 data\\001 price_data\\crude_oil_price\\Crude Oil WTI Futures Historical Data.csv")
full_history_df.Date=pd.DatetimeIndex(full_history_df.Date)
full_history_df.columns=["Date","Price","Open","High","Low","volume","change_percentage"]
full_history_df=full_history_df[::-1]
full_history_df=full_history_df.set_index("Date",drop=False)
history_since_news_df=full_history_df.loc[first_date:]
history_since_news_df.head()
# history_since_news_df.to_csv("C:\\Users\\Evan\\MyFile\\Fortune-street\\007 oil_price\
# \\oilprice_news_analyze\\002 data\\001 price_data\\crude_oil_price\\Crude Oil WTI Futures Historical Data_haha.csv")

full_news_df.loc[:,'news_publish_date']=pd.DatetimeIndex(full_news_df.loc[:,'news_publish_date'])

# %% [markdown]
# # define functions for conveniency

# %%
def get_news_by_date(start,end=None):
    START=start
    if not end:
        END=START
    else:
        END=end
    out=full_news_df.loc[full_news_df['news_publish_date']>=START,:]
    out=out.loc[out['news_publish_date']<=END,:]
    return(out)

def get_news_by_dates(dates):
    out=full_news_df.loc[full_news_df['news_publish_date'].isin(dates),:]
#     out=out.loc[out['news_publish_date']<=END,:]
    return(out)

# %% [markdown]
# # observe change_percentage

# %%
if type(history_since_news_df['change_percentage'][0])==str:
    history_since_news_df['change_percentage']=history_since_news_df['change_percentage'].apply(lambda x :float(x[:-1]))
print("['change_percentage'].abs().mean()",history_since_news_df['change_percentage'].abs().mean())
print("['change_percentage'].abs().std()",history_since_news_df['change_percentage'].abs().std())
history_since_news_df['change_percentage'].abs().hist()

print(history_since_news_df['change_percentage'].count())
big_change_date=history_since_news_df.loc[history_since_news_df['change_percentage'].abs()>3].index
# Out:
# ['change_percentage'].abs().mean() 1.6206976744186046
# ['change_percentage'].abs().std() 1.468391509499765
# 86

# %% [markdown]
# # draw big_change_date

# %%
from pandas.plotting import register_matplotlib_converters
import matplotlib.dates as mdates

fig=plt.figure(figsize=(32,16))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
# plt.gca().xaxis.set_major_locator(mdates.DayLocator())
register_matplotlib_converters()


xt=pd.Series(pd.date_range("2018-12-01","2019-03-31",freq="5D")).apply(pd.to_datetime)
plt.xticks(xt,rotation=90)
plt.yticks(np.arange(42,60,0.5))
plt.plot(history_since_news_df.loc[:,"Date"],history_since_news_df.loc[:,"Price"],linewidth=2)
plt.plot(history_since_news_df.loc[history_since_news_df.Date.isin(big_change_date-pd.Timedelta("1D")),"Price"],"or")

plt.grid(True,linestyle='-.')
plt.show()
plt.savefig("./big_change.png")

# %% [markdown]
# # apply stopwords

# %%
from collections import Counter
from nltk.corpus import stopwords
#define the pos_date & neg_date
neg_date=history_since_news_df.loc[history_since_news_df['change_percentage']<-3].index
pos_date=history_since_news_df.loc[history_since_news_df['change_percentage']>3].index
# get stopWords from nltk
stopWords =set(stopwords.words('english'))
human_stopWords=['']
def stop_words_filter(aListOfTokens,stopwords=None):
    new_l=[token for token in aListOfTokens if token not in stopwords]
    return(new_l)

corpus_for_vectorizer=full_news_df.news_tokens_list.apply(lambda x: " ".join(x))
vectorizer=TfidfVectorizer(max_df=0.7,min_df=15)
vectorizer.fit(corpus_for_vectorizer)
defined_stopwords=vectorizer.stop_words_
defined_stopwords.update(stopWords)
defined_stopwords.add('')

full_news_df['news_tokens_list_stripped']=full_news_df.news_tokens_list.\
apply(stop_words_filter,\
      stopwords=defined_stopwords)

# %% [markdown]
# # get tfidf vec of pos and neg

# %%
# get counter of each category
all_counter=Counter()
# for t_date in history_since_news_df.index:
#     aListOfToken=get_news_by_date(t_date).news_tokens_list_stripped
#     for tokens in aListOfToken:
#         all_counter.update(tokens)
aListOfToken=get_news_by_dates(history_since_news_df.index).news_tokens_list_stripped
for_vectorizer=aListOfToken.apply(lambda x: " ".join(x))
all_vec=vectorizer.transform(for_vectorizer)
aListOfToken.apply(lambda x: all_counter.update(x))
# for tokens in aListOfToken:
#     all_counter.update(tokens)

pos_counter=Counter()
# for t_date in pos_date-pd.Timedelta("1D"):
#     aListOfToken=get_news_by_date(t_date).news_tokens_list_stripped
#     for_vectorizer=aListOfToken.apply(lambda x: " ".join(x))
#     vec=vectorizer.transform(for_vectorizer)
#     print(vec)
#     for tokens in aListOfToken:
#         pos_counter.update(tokens)
        
aListOfToken=get_news_by_dates(pos_date-pd.Timedelta("1D")).news_tokens_list_stripped
for_vectorizer=aListOfToken.apply(lambda x: " ".join(x))
pos_vec=vectorizer.transform(for_vectorizer)
for tokens in aListOfToken:
    pos_counter.update(tokens)
        
        
neg_counter=Counter()
# for t_date in neg_date-pd.Timedelta("1D"):
#     aListOfToken=get_news_by_date(t_date).news_tokens_list_stripped
#     for tokens in aListOfToken:
#         neg_counter.update(tokens)
aListOfToken=get_news_by_dates(neg_date-pd.Timedelta("1D")).news_tokens_list_stripped
for_vectorizer=aListOfToken.apply(lambda x: " ".join(x))
neg_vec=vectorizer.transform(for_vectorizer)
for tokens in aListOfToken:
    neg_counter.update(tokens)
#
# pd.DataFrame.from_dict(all_counter,orient='index',columns=['all_count']).head()

# %% [markdown]
# # find keywords with a naive way

# %%
print("pos-neg",(pos_counter-neg_counter).most_common(40),"\n")
print("neg-pos",(neg_counter-pos_counter).most_common(40))
# Out:
# pos-neg [('trade', 164), ('tuesday', 89), ('new', 76), ('imports', 69), ('gas', 66), ('beijing', 61), ('talks', 61), ('december', 60), ('lng', 60), ('states', 57), ('euro', 51), ('demand', 47), ('chinese', 47), ('hit', 43), ('hopes', 42), ('diesel', 42), ('risk', 40), ('two', 40), ('dispute', 39), ('points', 39), ('well', 38), ('york', 38), ('thursday', 38), ('supply', 37), ('world', 37), ('bank', 37), ('recession', 37), ('deal', 36), ('change', 33), ('air', 33), ('officials', 32), ('exports', 32), ('copper', 31), ('positions', 30), ('supported', 29), ('rose', 29), ('huawei', 29), ('year', 28), ('united', 28), ('net', 28)]
#
# ...

# %% [markdown]
# # find keywords of pos_vec by minus mean of all_vec

# %%
all_vec_mean=np.array(all_vec.mean(axis=0))[0]
a=np.array(pos_vec.mean(axis=0))[0]-all_vec_mean
keyword_index=np.argwhere(a>0.005).reshape(1,-1)[0]
feature_names=vectorizer.get_feature_names()
aList=[]
for i in keyword_index:
    aList.append(feature_names[i])

# %%
sorted(zip(a[keyword_index].tolist(),aList),key=lambda atuple:atuple[0],reverse=True)
# Out:
# [(0.014739537783220364, 'trade'),
#  (0.012264784828320231, 'jan'),
#  (0.012105036954528777, 'december'),
#  (0.011895448515047913, 'imports'),
#  (0.011515875063206529, 'china'),
#  (0.010536262016827055, 'futures'),
#  (0.010457537088336856, 'demand'),
#  (0.01026891016022631, 'beijing'),
#  (0.00981513639425604, 'dispute'),
#  (0.00928816121088667, 'monday'),
#  (0.00884054454215243, 'lng'),
#  (0.008511594312195194, 'audi'),
#  (0.008419321156062977, 'wti'),
#  (0.00838721666712231, 'chinese'),
#  (0.008134410484869434, 'hopes'),
#  (0.007725918995589869, 'tuesday'),
#  (0.007158085589749293, 'barrel'),
#  (0.007079325329748384, 'resolve'),
#  (0.007070039667679027, 'talks'),
#  (0.00678941036054455, 'positions'),
#  (0.006707101256312667, 'fsru'),
#  (0.006703557000214151, 'huawei'),
#  (0.006667150549841579, 'euro'),
#  (0.0066336916449697084, 'copper'),
#  (0.006559425339850194, 'air'),
#  (0.0065228137601051565, 'pollution'),
#  (0.006508383772619299, 'ratings'),
# ...
